# %%
# load pandas
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# load Playgrounds data from WPRDC
playground_data = pd.read_csv("https://data.wprdc.org/datastore/dump/47350364-44a8-4d15-b6e0-5f79ddff9367",
                           index_col="id") # using id as row index

# random 10 rows to make sure it works
playground_data.sample(10)
# Out:
#                                     name  type maintenance_responsibility  \
# id
# 966240511    Brighton Heights Playground   NaN           Parks - Northern
# 1340656731        Monongahela Playground   NaN           Parks - Southern
# 1159646462  Vietnam Veteran's Playground   NaN           Parks - Schenley
# 481264091    McKinley Bausman Playground   NaN           Parks - Southern
# 536446250             Osceola Playground   NaN          Parks - Northeast
# 1371171404            McBride Playground   NaN           Parks - Southern
# 589541836             Frazier Playground   NaN           Parks - Schenley
# 1097984790          McGonigle Playground   NaN            Parks - Western
# 2024492541         North Ave. Playground   NaN           Parks - Northern
# 130973977           Chartiers Playground   NaN            Parks - Western
#
#                              park             street  \
# id
# 966240511   Brighton Heights Park  BRIGHTON WOODS RD
# 1340656731       Monongahela Park       JOSEPHINE ST
# 1159646462          Schenley Park        OVERLOOK DR
# 481264091           McKinley Park         BAUSMAN ST
# 536446250            Osceola Park         OSCEOLA ST
# 1371171404           McBride Park        MCBRIDE AVE
# 589541836            Frazier Park         FRAZIER ST
# 1097984790         McGonigle Park       ALLENDALE ST
# 2024492541      Allegheny Commons        W NORTH AVE
# 130973977          Chartiers Park      CHARTIERS AVE
#
#                                                         image  \
# id
# 966240511   https://tools.wprdc.org/images/pittsburgh/play...
# 1340656731  https://tools.wprdc.org/images/pittsburgh/play...
# 1159646462  https://tools.wprdc.org/images/pittsburgh/play...
# 481264091                                                 NaN
# 536446250   https://tools.wprdc.org/images/pittsburgh/play...
# 1371171404  https://tools.wprdc.org/images/pittsburgh/play...
# 589541836   https://tools.wprdc.org/images/pittsburgh/play...
# 1097984790  https://tools.wprdc.org/images/pittsburgh/play...
# 2024492541  https://tools.wprdc.org/images/pittsburgh/play...
# 130973977   https://tools.wprdc.org/images/pittsburgh/play...
#
#                    neighborhood  council_district  ward        tract  \
# id
# 966240511      Brighton Heights                 1    27  42003270800
# 1340656731    South Side Slopes                 3    16  42003160800
# 1159646462  Squirrel Hill South                 5    14  42003980500
# 481264091           Beltzhoover                 4    18  42003562400
# 536446250            Bloomfield                 7     8  42003080400
# 1371171404        Lincoln Place                 5    31  42003310200
# 589541836         South Oakland                 3     4  42003040900
# 1097984790             Sheraden                 2    20  42003562500
# 2024492541     Allegheny Center                 1    22  42003562700
# 130973977               Windgap                 2    28  42003563000
#
#             public_works_division  pli_division  police_zone fire_zone  \
# id
# 966240511                       1            27            1      1-14
# 1340656731                      3            16            3      4-22
# 1159646462                      3            14            4       2-8
# 481264091                       5            18            3       4-7
# 536446250                       2             8            5       3-1
# 1371171404                      3            31            4      4-20
# 589541836                       3             4            4      2-11
# 1097984790                      5            20            6      1-16
# 2024492541                      1            22            1       1-7
# 130973977                       5            28            6      1-16
#
#              latitude  longitude
# id
# 966240511   40.486669 -80.031856
# 1340656731  40.421902 -79.965743
# 1159646462  40.434223 -79.944239
# 481264091   40.412958 -79.998067
# 536446250   40.456842 -79.942312
# 1371171404  40.370431 -79.907322
# 589541836   40.429215 -79.953910
# 1097984790  40.459768 -80.065136
# 2024492541  40.454539 -80.010268
# 130973977   40.457028 -80.075011

# %%
# makes new dataframe of how many playgrounds are in each neigborhood
tally = playground_data['neighborhood'].value_counts().rename_axis('neighborhood').reset_index(name='counts')

tally
# Out:
#            neighborhood  counts
# 0   Squirrel Hill South       8
# 1     South Side Slopes       5
# 2             Beechview       5
# 3         Highland Park       4
# 4      Allegheny Center       4
# ..                  ...     ...
# 62              Bon Air       1
# 63        Spring Garden       1
# 64              Oakwood       1
# 65            Shadyside       1
# 66          Perry North       1
#
# [67 rows x 2 columns]
